# %%
file_path = "/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Time/train.txt.ori"
retag_dict = {"QUANTITY" : "O","ORDINAL":"O", "CARDINAL":"O", "PERCENT":"O"}
number_of_retag = 0
with open(file_path, "r") as f:
    lines = f.readlines()
    retagged_lines = []
    for line in lines:
        fields = line.split()
        if len(fields) > 1 :
            if fields[1] != "O":
                bio = fields[1].split("-")[0]
                tag = fields[1].split("-")[1]
                if tag in retag_dict.keys() :
                    retagged_lines.append(fields[0]+" "+bio+"-"+retag_dict[tag])
                    print(" Retag {} to {}".format(fields[1], retag_dict[tag]))
                    number_of_retag += 1
print("Total number of retag : {}".format(number_of_retag))
# Out:
#  Retag B-QUANTITY to O
#  Retag I-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag I-QUANTITY to O
#  Retag I-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-ORDINAL to O
#  Retag B-ORDINAL to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-ORDINAL to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-CARDINAL to O
#  Retag B-CARDINAL to O
#  Retag B-PERCENT to O
#  Retag I-PERCENT to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
#  Retag B-QUANTITY to O
# ...

# %%
-

# %%
retag("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Numbers_Time/train.txt.ori",{"CARDINAL":"O", "PERCENT":"O","MONEY":"O","ORDINAL":"O","QUANTITY":"O","DATE":"O", "TIME":"O"})
retag("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Numbers_Time/train.txt",{"CARDINAL":"O", "PERCENT":"O","MONEY":"O","ORDINAL":"O","QUANTITY":"O","DATE":"O", "TIME":"O"})
retag("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Numbers_Time/dev.txt",{"CARDINAL":"O", "PERCENT":"O","MONEY":"O","ORDINAL":"O","QUANTITY":"O","DATE":"O", "TIME":"O"})
retag("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Numbers_Time/test.txt",{"CARDINAL":"O", "PERCENT":"O","MONEY":"O","ORDINAL":"O","QUANTITY":"O","DATE":"O", "TIME":"O"})
# Out:
# Total number of retag : 64072
# 913219
# Total number of retag : 64072
# 913219
# Total number of retag : 11026
# 153854
# Total number of retag : 4828
# 63084
# (['While O\n',
#   'residents O\n',
#   'of O\n',
#   'the O\n',
#   'richest O\n',
#   'province O\n',
#   'in O\n',
#   'Bolivia O\n',
#   ', O\n',
#   'Santa O\n',
#   'Cruz O\n',
#   ', O\n',
#   'were O\n',
#   'fervently O\n',
#   'celebrating O\n',
#   'the O\n',
#   'victory O\n',
#   'of O\n',
#   'a O\n',
#   'referendum O\n',
#   'on O\n',
#   'autonomy O\n',
#   ', O\n',
#   'President O\n',
#   'Morales O\n',
#   'warned O\n',
#   'that O\n',
#   'the O\n',
#   'referendum O\n',
#   'was O\n',
#   '" O\n',
#   'illegal O\n',
#   'and O\n',
#   'unconstitutional O\n',
#   '" O\n',
#   '. O\n',
#   '\n',
#   'In O\n',
#   'a O\n',
#   'speech O\n',
#   'broadcast O\n',
#   'to O\n',
#   'the O\n',
#   'nation O\n',
#   ', O\n',
#   'Morales O\n',
#   'said O\n',
#   ', O\n',
#   '" O\n',
#   'The O\n',
# ...

# %%
for idx, el in enumerate(lines):
    ori_token = lines[idx].split()
    if len(ori_token) > 1:
        retag_token = retagged_lines[idx].split()
        if ori_token[0] != retag_token[0] :
            print("Something is wrong {} {}".format(ori_token, retag_token))

# %%
with open("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/OntoNotes_NW_Without_Time/train.txt.ori.retag", "w") as f:
    for line in retagged_lines :
        f.write(line)
