# %%
import os
import sys
from collections import defaultdict
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

from util.CoNLL import readCoNLL, readOntoNotes

# %%
sentences = readCoNLL("/Users/slouvan/sandbox/emnlp2017-bilstm-cnn-crf/data/CONLL_2003_NER/train.txt.ori", {0:'tokens', 1:'label'})

# %%
unique_tokens = set()
for sentence in sentences:
    tokens = sentence['tokens']
    for token in tokens:
        unique_tokens.add(token)
len(sentences),len(unique_tokens)
# Out:
# (14987, 23624)

# %%
sorted(list(unique_tokens))
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "''",
#  "'30s",
#  "'40s",
#  "'50s",
#  "'60s",
#  "'68",
#  "'70's",
#  "'70s",
#  "'71",
#  "'80's",
#  "'80s",
#  "'86",
#  "'90's",
#  "'90s",
#  "'94",
#  "'96",
#  "'97",
#  "'98",
#  "'N",
#  "'S",
#  "'T-",
#  "'d",
#  "'em",
#  "'ll",
#  "'m",
#  "'n'",
#  "'re",
#  "'s",
#  "'til",
#  "'ve",
#  ',',
#  '-',
#  '--',
#  '---',
#  '-0.06',
#  '-LCB-',
#  '-LRB-',
#  '-RCB-',
#  '-RRB-',
#  '.',
#  '...',
#  '.270',
#  '.84',
#  '.95',
#  '.what',
#  '/',
#  '0',
#  '0.0002',
#  '0.0015',
#  '0.01',
#  '0.02',
#  '0.025',
#  '0.03',
#  '0.05',
#  '0.07',
#  '0.1',
#  '0.10',
#  '0.12',
#  '0.13',
#  '0.14',
#  '0.15',
#  '0.16',
#  '0.17',
#  '0.19',
#  '0.2',
#  '0.20',
#  '0.23',
#  '0.24',
#  '0.25',
#  '0.26',
#  '0.272',
#  '0.28',
#  '0.3',
#  '0.32',
#  '0.35',
#  '0.37',
#  '0.4',
#  '0.43',
#  '0.45',
#  '0.5',
#  '0.50',
#  '0.53',
#  '0.59',
#  '0.6',
#  '0.60',
#  '0.63',
#  '0.65',
#  '0.7',
#  '0.75',
# ...
